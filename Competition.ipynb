# %%
# !pip install scikit-learn
# !pip install pandas
import sklearn
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
data1 = pd.read_csv(r'/Users/simgesargin/Desktop/Bootcamp/housing-classification-iter6.csv')
data1.columns
data1
# Out:
#       LotArea  LotFrontage  TotalBsmtSF  BedroomAbvGr  Fireplaces  PoolArea  \
# 0        8450         65.0          856             3           0         0
# 1        9600         80.0         1262             3           1         0
# 2       11250         68.0          920             3           1         0
# 3        9550         60.0          756             3           1         0
# 4       14260         84.0         1145             4           1         0
# ...       ...          ...          ...           ...         ...       ...
# 1455     7917         62.0          953             3           1         0
# 1456    13175         85.0         1542             3           2         0
# 1457     9042         66.0         1152             4           2         0
# 1458     9717         68.0         1078             2           0         0
# 1459     9937         75.0         1256             3           0         0
#
# ...

# %%
data2 = pd.read_csv(r'/Users/simgesargin/Desktop/Bootcamp/test-housing-classification.csv')
data2.columns
data2
# Out:
#       LotArea  LotFrontage  TotalBsmtSF  BedroomAbvGr  Fireplaces  PoolArea  \
# 0       11622         80.0        882.0             2           0         0
# 1       14267         81.0       1329.0             3           0         0
# 2       13830         74.0        928.0             3           1         0
# 3        9978         78.0        926.0             3           1         0
# 4        5005         43.0       1280.0             2           0         0
# ...       ...          ...          ...           ...         ...       ...
# 1454     1936         21.0        546.0             3           0         0
# 1455     1894         21.0        546.0             3           0         0
# 1456    20000        160.0       1224.0             4           1         0
# 1457    10441         62.0        912.0             3           0         0
# 1458     9627         74.0        996.0             3           1         0
#
# ...

# %%
X = data1
y = X.pop("Expensive")


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
X_train.head()
# Out:
#      LotArea  LotFrontage  TotalBsmtSF  BedroomAbvGr  Fireplaces  PoolArea  \
# 318     9900         90.0         1347             4           1         0
# 580    14585          NaN         1144             3           2         0
# 961    12227          NaN         1330             4           1         0
# 78     10778         72.0         1768             4           0         0
# 5      14115         85.0          796             1           0         0
#
#      GarageCars  WoodDeckSF  ScreenPorch MSZoning  ... GarageType  \
# 318           3         340            0       RL  ...     Attchd
# 580           2         216            0       RL  ...     Attchd
# 961           2         550            0       RL  ...     Attchd
# 78            0           0            0       RL  ...        NaN
# 5             2          40            0       RL  ...     Attchd
#
#     GarageFinish GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature  \
# ...

# %%
X_cat_columns = X.select_dtypes(exclude="number").copy().columns
X_num_columns = X.select_dtypes(include="number").copy().columns


numeric_pipe = make_pipeline(
    SimpleImputer(strategy="mean"))
 

categoric_pipe = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="N_A"),
    OneHotEncoder(sparse_output=False, handle_unknown='ignore')
)

# %%
from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer(
    transformers=[
        ("num_pipe", numeric_pipe, X_num_columns), 
        ("cat_pipe", categoric_pipe, X_cat_columns), 
    ]
)

# %%
full_pipeline = make_pipeline(preprocessor, 
                              DecisionTreeClassifier()).set_output(transform='pandas')

# %%
full_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_pipe',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer())]),
#                                                   Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch', 'MSSubClass',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'BsmtFinSF1'...
#        'Neighborhood', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'BsmtFinType2',
#        'HeatingQC', 'Electrical', 'Functional', 'GarageType', 'GarageFinish',
#        'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence',
#        'MiscFeature', 'SaleType', 'SaleCondition'],
#       dtype='object'))])),
# ...

# %%
full_pipeline.predict(X_train)
# Out:
# array([1, 0, 1, ..., 1, 0, 0])

# %%
param_grid = {
    "columntransformer__num_pipe__simpleimputer__strategy":["mean", "median"],
    "decisiontreeclassifier__max_depth": range(2, 14),
    "decisiontreeclassifier__min_samples_leaf": range(3, 10),
    "decisiontreeclassifier__criterion":["gini", "entropy"]
}

# %%
search = GridSearchCV(full_pipeline,
                      param_grid,
                      cv=5,
                      verbose=1, 
                      error_score='raise')

# %%
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 336 candidates, totalling 1680 fits
# GridSearchCV(cv=5, error_score='raise',
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('num_pipe',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer())]),
#                                                                          Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch', 'MSSubClass',
#        'OverallQual', 'OverallCond', 'Yea...
#        'MiscFeature', 'SaleType', 'SaleCondition'],
#       dtype='object'))])),
#                                        ('decisiontreeclassifier',
#                                         DecisionTreeClassifier())]),
# ...

# %%
y_train_pred = search.predict(X_train)

train_accuracy = accuracy_score(y_train, y_train_pred)

train_accuracy_rounded = round(train_accuracy, 4)

print("The training data prediction is {:.2%} accurate".format(train_accuracy_rounded))
# Out:
# The training data prediction is 95.72% accurate

# %%
y_test_pred = search.predict(X_test)

test_accuracy = accuracy_score(y_test, y_test_pred)

test_accuracy_rounded = round(test_accuracy, 4)

print("The test data prediction is {:.2%} accurate".format(test_accuracy_rounded))
# Out:
# The test data prediction is 95.21% accurate

# %%
path ='/Users/simgesargin/Desktop/Bootcamp/test-housing-classification.csv'

data_last = pd.read_csv(path)

# %%
last_data_test = search.predict(data_last)
last_data_test_2 = pd.DataFrame(last_data_test, columns=["Expensive"])
last_data_test_2.index.rename("Id", inplace=True)
#final_data_test_1.reset_index(inplace=True)
last_data_test_2.head(1)
# Out:
#     Expensive
# Id
# 0           0

# %%
data_last.Id
# Out:
# 0       1461
# 1       1462
# 2       1463
# 3       1464
# 4       1465
#         ...
# 1454    2915
# 1455    2916
# 1456    2917
# 1457    2918
# 1458    2919
# Name: Id, Length: 1459, dtype: int64

# %%
last_data_test_2.to_csv(path+"challange_submission_decisiontree.csv")

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
full_pipeline = make_pipeline(preprocessor, 
                              KNeighborsClassifier()).set_output(transform='pandas')

# %%
full_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_pipe',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer())]),
#                                                   Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch', 'MSSubClass',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'BsmtFinSF1'...
#        'Neighborhood', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'BsmtFinType2',
#        'HeatingQC', 'Electrical', 'Functional', 'GarageType', 'GarageFinish',
#        'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence',
#        'MiscFeature', 'SaleType', 'SaleCondition'],
#       dtype='object'))])),
# ...

# %%
param_grid = {
    "columntransformer__num_pipe__simpleimputer__strategy":["mean", "median"],
    "kneighborsclassifier__n_neighbors": range(1, 10),
    "kneighborsclassifier__p": range(1, 2), 
    "kneighborsclassifier__weights":["uniform", "distance"]
}

# %%
search = GridSearchCV(full_pipeline,
                      param_grid,
                      cv=5,
                      verbose=1, 
                      error_score='raise')

# %%
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# GridSearchCV(cv=5, error_score='raise',
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('num_pipe',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer())]),
#                                                                          Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch', 'MSSubClass',
#        'OverallQual', 'OverallCond', 'Yea...
#        'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence',
#        'MiscFeature', 'SaleType', 'SaleCondition'],
#       dtype='object'))])),
#                                        ('kneighborsclassifier',
# ...

# %%
y_train_pred = search.predict(X_train)

train_accuracy = accuracy_score(y_train, y_train_pred)

train_accuracy_rounded = round(train_accuracy, 4)

print("The training data prediction is {:.2%} accurate".format(train_accuracy_rounded))
# Out:
# The training data prediction is 100.00% accurate

# %%
y_test_pred = search.predict(X_test)

test_accuracy = accuracy_score(y_test, y_test_pred)

test_accuracy_rounded = round(test_accuracy, 4)

print("The test data prediction is {:.2%} accurate".format(test_accuracy_rounded))
# Out:
# The test data prediction is 92.81% accurate

# %%
path ='/Users/simgesargin/Desktop/Bootcamp/test-housing-classification.csv'

data_last = pd.read_csv(path)

# %%
last_data_test = search.predict(data_last)
last_data_test_1 = pd.DataFrame(last_data_test, columns=["Expensive"])
last_data_test_1.index.rename("Id", inplace=True)
#final_data_test_1.reset_index(inplace=True)
last_data_test_1.head(1)
# Out:
#     Expensive
# Id
# 0           0

# %%
last_data_test_1.to_csv(path+"challange_submission_knn.csv")

# %%
full_pipeline.predict(data_last)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
data_last['Expensive'] = full_pipeline.predict(data_last)

# %%
data_last[['Id','Expensive']].to_csv(path+"challange_submission_knn.csv", index=False)

# %%
from sklearn.linear_model import LogisticRegression

# %%
#Creating the full pipeline
full_pipeline = make_pipeline(preprocessor, 
                              LogisticRegression()).set_output(transform='pandas')

# %%
#Fit
full_pipeline.fit(X_train, y_train)
# Out:
# /Users/simgesargin/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_pipe',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer())]),
#                                                   Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
# ...

# %%
#Create parameter grid
param_grid = {
    "columntransformer__num_pipe__simpleimputer__strategy":["mean", "median"],
    #"logisticregression__penalty": ["l2", None],
    "logisticregression__solver": ["lbfgs", "liblinear", "newton-cg", "newton-cholesky", "sag", "saga"]
}

# %%
#Define cross validation
search = GridSearchCV(full_pipeline,
                      param_grid,
                      cv=5,
                      verbose=1, 
                      error_score='raise')

# %%
#Fit 
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# /Users/simgesargin/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/simgesargin/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
search.best_params_
# Out:
# {'columntransformer__num_pipe__simpleimputer__strategy': 'mean',
#  'logisticregression__solver': 'newton-cg'}

# %%
#Training accuracy
y_train_pred = search.predict(X_train)

train_accuracy = accuracy_score(y_train, y_train_pred)

train_accuracy_rounded = round(train_accuracy, 4)

print("The training data prediction is {:.2%} accurate".format(train_accuracy_rounded))
# Out:
# The training data prediction is 97.09% accurate

# %%
#Testing accuracy
y_test_pred = search.predict(X_test)

test_accuracy = accuracy_score(y_test, y_test_pred)

test_accuracy_rounded = round(test_accuracy, 4)

print("The test data prediction is {:.2%} accurate".format(test_accuracy_rounded))
# Out:
# The test data prediction is 95.55% accurate

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#Creating the full pipeline
full_pipeline = make_pipeline(preprocessor, 
                              RandomForestClassifier()).set_output(transform='pandas')

# %%
#Fit
full_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num_pipe',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer())]),
#                                                   Index(['LotArea', 'LotFrontage', 'TotalBsmtSF', 'BedroomAbvGr', 'Fireplaces',
#        'PoolArea', 'GarageCars', 'WoodDeckSF', 'ScreenPorch', 'MSSubClass',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'BsmtFinSF1'...
#        'Neighborhood', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'BsmtFinType2',
#        'HeatingQC', 'Electrical', 'Functional', 'GarageType', 'GarageFinish',
#        'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence',
#        'MiscFeature', 'SaleType', 'SaleCondition'],
#       dtype='object'))])),
# ...

# %%
import numpy as np

# %%
#Create parameter grid
param_grid = {
    "columntransformer__num_pipe__simpleimputer__strategy":["mean", "median"],
    "randomforestclassifier__n_estimators": range(85,105),
    "randomforestclassifier__max_features": ["auto", "sqrt"], 
    "randomforestclassifier__max_depth":range(14,16),
    "randomforestclassifier__min_samples_split":range(2,5),
    "randomforestclassifier__min_samples_leaf":range(8,11)
}

# %%
#Define cross validation
search = GridSearchCV(full_pipeline,
                      param_grid,
                      cv=5,
                      verbose=1, 
                      error_score='raise')

# %%
#Fit 
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 1440 candidates, totalling 7200 fits
# /Users/simgesargin/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /Users/simgesargin/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# ...

# %%
search.best_params_
# Out:
# {'columntransformer__num_pipe__simpleimputer__strategy': 'mean',
#  'randomforestclassifier__max_depth': 15,
#  'randomforestclassifier__max_features': 'auto',
#  'randomforestclassifier__min_samples_leaf': 8,
#  'randomforestclassifier__min_samples_split': 4,
#  'randomforestclassifier__n_estimators': 95}

# %%
#Testing accuracy
y_test_pred = search.predict(X_test)

test_accuracy = accuracy_score(y_test, y_test_pred)

test_accuracy_rounded = round(test_accuracy, 4)

print("The test data prediction is {:.2%} accurate".format(test_accuracy_rounded))
# Out:
# The test data prediction is 95.21% accurate

# %%
path ='/Users/simgesargin/Desktop/Bootcamp/test-housing-classification.csv'

data_last = pd.read_csv(path)

# %%
last_data_test = search.predict(data_last)
last_data_test_1 = pd.DataFrame(last_data_test, columns=["Expensive"])
last_data_test_1.index.rename("Id", inplace=True)
#final_data_test_1.reset_index(inplace=True)
last_data_test_1.head(1)
# Out:
#     Expensive
# Id
# 0           0

# %%
last_data_test_1.to_csv(path+"challange_submission_knn.csv")

# %%
data_last['Expensive'] = full_pipeline.predict(data_last)

# %%
data_last[['Id','Expensive']].to_csv(path+"challange_submission_knn.csv", index=False)
